# %%
A_dic = {1:'식품', 2:'패션잡화', 3:'아동', 4:'패션의류_여성', 5:'패션의류_남성', 6:'스포츠', 7:'가전', 8:'명품', 9:'가구/인테리어'}
B_dic = {10:'농산물', 11:'반찬', 12:'잡곡', 13:'수산물', 14:'편의시설', 15:'조리식품', 16:'가공식품', 17:'조미료/소스' ,18:'커피/차', 19:'간식', 20:'음료', 21:'주류', 22:'가정용품',
        23:'생활용품', 24:'가구/인테리어', 25:'문구/공구', 26:'아동', 27:'애완/동물물품', 28:'자동차', 29:'패션의류-여성', 30:'패션의류-남성', 31:'언더웨어', 32:'뷰티', 33:'스포츠', 34:'음식점', 35:'가전',
        36:'패션잡화', 37:'축산물', 38:'과일', 39:'건강'}
C_dic = {40:'과일', 41:'농산물', 42:'수산물', 43:'축산물', 44:'조리식품/간식', 45:'가공식품', 46:'냉장/냉동식품', 47:'음료', 48:'주류', 49:'가공식품/건강', 50:'조미료/소스', 51:'간식', 52:'가정용품'}       
D_dic = {53:'기초케어', 54:'바디케어', 55:'건강케어', 56:'간식', 57:'편의용품', 58:'향수', 59:'메이크업'}


def big_code_name_col(x):
    if x in dict_big_code: 
        return dict_big_code[x]     
    else:
        return None            # 만약에 대분류 안하면 그냥 숫자값으로 줌
prodcat['대분류명'] = prodcat['대분류코드'].apply(big_code_name_col)
