# %%
import pandas as pd

# %%
df_product = pd.read_csv('LOTT/구매상품TR.txt',sep=',',encoding='cp949')

df_product.head()
# Out:
#   제휴사    영수증번호  대분류코드  중분류코드    소분류코드   고객번호  점포코드      구매일자  구매시간  구매금액
# 0   B  8664000     15   1504  B150401  17218    44  20140222    20  2420
# 1   B  8664000     16   1601  B160101  17218    44  20140222    20  1070
# 2   B  8664000     16   1602  B160201  17218    44  20140222    20  8060
# 3   B  8664000     18   1803  B180301  17218    44  20140222    20  6000
# 4   B  8664001      5    509  B050901  17674    44  20140222    22  1120

# %%
df_product.groupby('영수증번호')['구매금액'].sum().sort_values(ascending=False)
# Out:
# 영수증번호
# 1416069     101330000
# 1500785     101110000
# 1677262      99960000
# 5526155      93654000
# 3569101      93166350
#               ...
# 5871720            10
# 10458158           10
# 5871721            10
# 5871722            10
# 641097             10
# Name: 구매금액, Length: 11086939, dtype: int64

# %%
print('대분류 코드 갯수:' , df_product['대분류코드'].nunique())
# Out:
# 대분류 코드 갯수: 92

# %%
print('고객수:',df_product['고객번호'].nunique())
# Out:
# 고객수: 19383

# %%
membership_count = pd.DataFrame(df_product[['제휴사']].value_counts(),columns=['count'])
membership_count
# Out:
#         count
# 제휴사
# B    13338074
# C     9379236
# A     5770318
# D      105402

# %%
df_product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28593030 entries, 0 to 28593029
# Data columns (total 10 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   제휴사     object
#  1   영수증번호   int64
#  2   대분류코드   int64
#  3   중분류코드   int64
#  4   소분류코드   object
#  5   고객번호    int64
#  6   점포코드    int64
#  7   구매일자    int64
#  8   구매시간    int64
#  9   구매금액    int64
# dtypes: int64(8), object(2)
# memory usage: 2.1+ GB

# %%
df_product['구매금액'].mean()
# Out:
# 23677.76891574625

# %%
df_product.groupby('고객번호')['고객번호'].count()
# Out:
# 고객번호
# 1        1057
# 2        1116
# 3        1191
# 4         930
# 5         719
#          ...
# 19379     584
# 19380     440
# 19381     805
# 19382     906
# 19383     260
# Name: 고객번호, Length: 19383, dtype: int64

# %%
df_product.groupby('고객번호')['구매금액'].mean().sort_values(ascending=False)[:10].astype(int)
# Out:
# 고객번호
# 14599    4648468
# 15999    4334747
# 16406    2680405
# 7957     2538535
# 8079     2429896
# 16005    2267099
# 13376    1796194
# 10487    1404958
# 11763    1375067
# 6207     1301821
# Name: 구매금액, dtype: int32

# %%
import pandas as pd

a = pd.read_pickle('dataset/연도별전체매출액.pkl')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-f60376502084> in <module>
#       1 import pandas as pd
#       2
# ----> 3 a = pd.read_pickle('dataset/연도별전체매출액.pkl')
#
# C:\anaconda3\envs\cakd3\lib\site-packages\pandas\io\pickle.py in read_pickle(filepath_or_buffer, compression, storage_options)
#     206                 #  "No module named 'pandas.core.sparse.series'"
#     207                 #  "Can't get attribute '__nat_unpickle' on <module 'pandas._libs.tslib"
# --> 208                 return pc.load(handles.handle, encoding=None)
#     209         except UnicodeDecodeError:
#     210             # e.g. can occur for files written in py27; see GH#28645 and GH#31988
#
# C:\anaconda3\envs\cakd3\lib\site-packages\pandas\compat\pickle_compat.py in load(fh, encoding, is_verbose)
#     247         up.is_verbose = is_verbose
#     248
# --> 249         return up.load()
#     250     except (ValueError, TypeError):
#     251         raise
#
# C:\anaconda3\envs\cakd3\lib\pickle.py in load(self)
#    1210                     raise EOFError
#    1211                 assert isinstance(key, bytes_types)
# -> 1212                 dispatch[key[0]](self)
#    1213         except _Stop as stopinst:
#    1214             return stopinst.value
#
# C:\anaconda3\envs\cakd3\lib\pickle.py in load_stack_global(self)
#    1535         if type(name) is not str or type(module) is not str:
#    1536             raise UnpicklingError("STACK_GLOBAL requires str")
# -> 1537         self.append(self.find_class(module, name))
#    1538     dispatch[STACK_GLOBAL[0]] = load_stack_global
#    1539
#
# C:\anaconda3\envs\cakd3\lib\site-packages\pandas\compat\pickle_compat.py in find_class(self, module, name)
#     187         key = (module, name)
#     188         module, name = _class_locations_map.get(key, key)
# --> 189         return super().find_class(module, name)
#     190
#     191
#
# C:\anaconda3\envs\cakd3\lib\pickle.py in find_class(self, module, name)
#    1579         __import__(module, level=0)
#    1580         if self.proto >= 4:
# -> 1581             return _getattribute(sys.modules[module], name)[0]
#    1582         else:
#    1583             return getattr(sys.modules[module], name)
#
# C:\anaconda3\envs\cakd3\lib\pickle.py in _getattribute(obj, name)
#     329             obj = getattr(obj, subpath)
#     330         except AttributeError:
# --> 331             raise AttributeError("Can't get attribute {!r} on {!r}"
#     332                                  .format(name, obj)) from None
#     333     return obj, parent
#
# AttributeError: Can't get attribute 'new_block' on <module 'pandas.core.internals.blocks' from 'C:\\anaconda3\\envs\\cakd3\\lib\\site-packages\\pandas\\core\\internals\\blocks.py'>
